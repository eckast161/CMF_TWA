# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
import matplotlib.pyplot as plt
import numpy as np
#from google.colab import files

"""In order to provide a better presentation of the graphs we use the rcParams options shown below."""

import matplotlib
matplotlib.rcParams['text.usetex'] = False
matplotlib.rcParams['mathtext.fontset'] = 'stix'
matplotlib.rcParams['font.family'] = 'STIXGeneral'
matplotlib.rcParams['font.size'] = 15
matplotlib.rcParams['figure.figsize'] = (11.0, 8.0)

from numpy import cos, sin

label_size = 20

from numpy import sqrt

import time
from numba import jit
from numpy import sin, cos

T0=time.time()

# %%
MACE4_0dot001=np.array(pd.read_csv('_MACE_AV__N_atom_192_Cluster_size_4_Max_step_0.001_Tspan_0.0-2.0_Signature_0.553071.txt')).astype(complex)

MACE5_0dot001=np.array(pd.read_csv('_MACE_AV__N_atom_192_Cluster_size_5_Max_step_0.001_Tspan_0.0-2.0_Signature_0.20405199999999998.txt')).astype(complex)

MACE5_0dot0001=np.array(pd.read_csv('_MACE_AV__N_atom_192_Cluster_size_5_Max_step_0.0001_Tspan_0.0-2.0_Signature_0.6783239999999999.txt')).astype(complex)

MACE6_0dot001=np.array(pd.read_csv('_MACE_AV__N_atom_192_Cluster_size_6_Max_step_0.001_Tspan_0.0-2.0_Signature_0.49997899999999995.txt')).astype(complex)

MACE7_0dot01=np.array(pd.read_csv('_MACE_AV__N_atom_192_Cluster_size_7_Max_step_0.01_Tspan_0.0-2.0_Signature_0.28303.txt')).astype(complex)



MACE8_0dot005=np.array(pd.read_csv('_MACE_AV__N_atom_192_Cluster_size_8_Max_step_0.005_Tspan_0.0-2.0_Signature_0.756664.txt')).astype(complex)

# %%
plt.title("MACE Cluster Approach",fontsize=30)




plt.plot(np.real(MACE4_0dot001[:,0]),np.real(MACE4_0dot001[:,1]),label="Cluster 4")
plt.plot(np.real(MACE5_0dot001[:,0]),np.real(MACE5_0dot001[:,1]),label="Cluster 5")
plt.plot(np.real(MACE6_0dot001[:,0]),np.real(MACE6_0dot001[:,1]),label="Cluster 6")
plt.plot(np.real(MACE7_0dot01[:,0]),np.real(MACE7_0dot01[:,1])  ,label="Cluster 7")
plt.plot(np.real(MACE8_0dot005[:,0]),np.real(MACE8_0dot005[:,1])  ,label="Cluster 8")

#plt.yscale("log")

#plt.xlim((0,0.1))
#plt.ylim((1.45,2))


plt.xlabel("$t$",fontsize=25)
plt.ylabel("$C_z\\left( t \\right)$",fontsize=25)

plt.savefig('MACE.png')
plt.savefig('MACE.pdf')

plt.legend()
