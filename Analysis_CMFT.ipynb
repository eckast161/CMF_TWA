# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#  http://localhost:8888/notebooks/Desktop/Sean

# %%
import matplotlib.pyplot as plt
import numpy as np
#from google.colab import files

"""In order to provide a better presentation of the graphs we use the rcParams options shown below."""

import matplotlib
matplotlib.rcParams['text.usetex'] = False
matplotlib.rcParams['mathtext.fontset'] = 'stix'
matplotlib.rcParams['font.family'] = 'STIXGeneral'
matplotlib.rcParams['font.size'] = 15
matplotlib.rcParams['figure.figsize'] = (11.0, 8.0)

from numpy import cos, sin

label_size = 20

from numpy import sqrt

import time
from numba import jit
from numpy import sin, cos

T0=time.time()

# %%
CMFT_Cs2=np.array(pd.read_csv('_NewCMFT_N_atom_192_Cluster_size_2_Max_step_0.1_Tspan_0.0-2.0_Signature_0.269309.txt')).astype(complex)

CMFT_Cs3=np.array(pd.read_csv('_NewCMFT_N_atom_192_Cluster_size_3_Max_step_0.1_Tspan_0.0-2.0_Signature_0.990734.txt')).astype(complex)

CMFT_Cs4=np.array(pd.read_csv('_NewCMFT_N_atom_192_Cluster_size_4_Max_step_0.1_Tspan_0.0-2.0_Signature_0.506437.txt')).astype(complex)

CMFT_Cs5=np.array(pd.read_csv('_NewCMFT_N_atom_192_Cluster_size_5_Max_step_0.1_Tspan_0.0-2.0_Signature_0.015127.txt')).astype(complex)


CMFT_Cs5N=np.array(pd.read_csv('_NewCMFT_N_atom_192_Cluster_size_5_Max_step_0.01_Tspan_0.0-2.0_Signature_0.932803.txt')).astype(complex)
CMFT_Cs6=np.array(pd.read_csv('_NewCMFT_N_atom_192_Cluster_size_6_Max_step_0.1_Tspan_0.0-2.0_Signature_0.822192.txt')).astype(complex)
#CMFT_Cs7=np.array(pd.read_csv('_CMFT_N_atom_192_Cluster_size_7_Max_step_0.1_Tspan_0.0-2.0_Signature_0.754259.txt')).astype(complex)


CMFT_Cs6M=np.array(pd.read_csv('_CMFT_N_atom_192_Cluster_size_6_Max_step_0.1_Tspan_0.0-2.0_Signature_0.300687.txt')).astype(complex)  
CMFT_Cs7=np.array(pd.read_csv('_NewCMFT_N_atom_192_Cluster_size_7_Max_step_0.1_Tspan_0.0-2.0_Signature_0.971405.txt')).astype(complex)

CMFT_Cs8=np.array(pd.read_csv('_NAWCMFT_N_atom_192_Cluster_size_8_Max_step_0.1_Tspan_0.0-2.0_Signature_0.710041.txt')).astype(complex)

# %%
plt.title("CMFT Approach",fontsize=30)


plt.plot(np.real(CMFT_Cs2[:,0]),np.real(CMFT_Cs2[:,1]),label="Cluster 2")
plt.plot(np.real(CMFT_Cs3[:,0]),np.real(CMFT_Cs3[:,1]),label="Cluster 3")
plt.plot(np.real(CMFT_Cs4[:,0]),np.real(CMFT_Cs4[:,1]),label="Cluster 4")
plt.plot(np.real(CMFT_Cs5[:,0]),np.real(CMFT_Cs5[:,1])  ,label="Cluster 5")
#plt.plot(np.real(CMFT_Cs5N[:,0]),np.real(CMFT_Cs5N[:,1]),"--"  ,label="Cluster 5")
plt.plot(np.real(CMFT_Cs6[:,0]),np.real(CMFT_Cs6[:,1])  ,label="Cluster 6")
plt.plot(np.real(CMFT_Cs7[:,0]),np.real(CMFT_Cs7[:,1])  ,label="Cluster 7")
plt.plot(np.real(CMFT_Cs8[:,0]),np.real(CMFT_Cs8[:,1])  ,label="Cluster 8")



#plt.yscale("log")

#plt.xlim((0,0.1))
#plt.ylim((1.45,2))


plt.xlabel("$t$",fontsize=25)
plt.ylabel("$C_z\\left( t \\right)$",fontsize=25)


plt.savefig('CMFT.png')
plt.savefig('CMFT.pdf')


plt.legend()
